# %%
import pandas as pd
df = pd.read_csv("kc_house_data.csv")

# %%
df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# ...

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
name = {"id": "ID", "date": "Date", "price": "Price", "bedrooms": "Bedrooms", "bathrooms": "Bathrooms", "sqft_living": "Sqft_Living", "sqft_lot": "Sqft_Lot", "floors": "Floors", "waterfront": "Waterfront", 
       "view": "View", "condition": "Condition", "grade": "Grade", "sqft_above": "Sqft_Above", "sqft_basement":"Sqft_Basement", "yr_built": "Yr_Built", "yr_renovated": "Yr_Renovated", 
        "zipcode": "Zipcode", "lat": "Lat", "long": "Long", "sqft_living15": "Sqft_Living15", "sqft_lot15": "Sqft_Lot15"}

# %%
df.rename(columns=name, inplace=True)

# %%
df.head()
# Out:
#            ID        Date     Price  Bedrooms  Bathrooms  Sqft_Living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    Sqft_Lot  Floors  Waterfront  View  ...  Grade  Sqft_Above  Sqft_Basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   Yr_Built  Yr_Renovated  Zipcode      Lat     Long  Sqft_Living15  Sqft_Lot15
# ...

# %% [markdown]
# # EDA

# %% [markdown]
# EDA vs. Data Mining:
#
# In EDA, you explore and compare different variables by using various techniques to find patterns. Data Mining, on the other hand, is more concerned about extracting the patterns out of the data itself.

# %%
# what I usually do
df.describe()
# Out:
#                  ID         Price      Bedrooms     Bathrooms   Sqft_Living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            Sqft_Lot        Floors    Waterfront          View     Condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
# create a function to show missing values and summary statistics
def eda(df):
    eda_df = {}
    eda_df["null_sum"] = df.isna().sum()
    eda_df["null_pct"] = df.isna().mean()
    eda_df["dtypes"] = df.dtypes
    eda_df["count"] = df.count()
    eda_df["mean"] = df.mean()
    eda_df["median"] = df.median()
    eda_df["min"] = df.min()
    eda_df["max"] = df.max()
    
    return pd.DataFrame(eda_df)

# %%
eda(df)
# Out:
#                null_sum  null_pct   dtypes  count          mean        median  \
# Bathrooms             0  0.000000  float64  21597  2.115826e+00  2.250000e+00
# Bedrooms              0  0.000000    int64  21597  3.373200e+00  3.000000e+00
# Condition             0  0.000000    int64  21597  3.409825e+00  3.000000e+00
# Date                  0  0.000000   object  21597           NaN           NaN
# Floors                0  0.000000  float64  21597  1.494096e+00  1.500000e+00
# Grade                 0  0.000000    int64  21597  7.657915e+00  7.000000e+00
# ID                    0  0.000000    int64  21597  4.580474e+09  3.904930e+09
# Lat                   0  0.000000  float64  21597  4.756009e+01  4.757180e+01
# Long                  0  0.000000  float64  21597 -1.222140e+02 -1.222310e+02
# Price                 0  0.000000  float64  21597  5.402966e+05  4.500000e+05
# Sqft_Above            0  0.000000    int64  21597  1.788597e+03  1.560000e+03
# ...

# %% [markdown]
# Ok, so this is called Data Profiling in EDA where you get a "feel" of the data by looking at the descriptive statistics.

# %%
df.head()
# Out:
#            ID        Date     Price  Bedrooms  Bathrooms  Sqft_Living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    Sqft_Lot  Floors  Waterfront  View  ...  Grade  Sqft_Above  Sqft_Basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   Yr_Built  Yr_Renovated  Zipcode      Lat     Long  Sqft_Living15  Sqft_Lot15
# ...

# %%
df.tail()
# Out:
#                ID        Date     Price  Bedrooms  Bathrooms  Sqft_Living  \
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        Sqft_Lot  Floors  Waterfront  View  ...  Grade  Sqft_Above  \
# 21592      1131     3.0         0.0   0.0  ...      8        1530
# 21593      5813     2.0         0.0   0.0  ...      8        2310
# 21594      1350     2.0         0.0   0.0  ...      7        1020
# 21595      2388     2.0         NaN   0.0  ...      8        1600
# 21596      1076     2.0         0.0   0.0  ...      7        1020
#
#        Sqft_Basement Yr_Built  Yr_Renovated  Zipcode      Lat     Long  \
# ...

# %%
# considering taking a sample of the dataset if it is too big
df.sample(5)
# Out:
#                ID       Date     Price  Bedrooms  Bathrooms  Sqft_Living  \
# 12130  3260590070   8/1/2014  744000.0         4       2.50         3140
# 8751   9194101388  9/19/2014  540000.0         3       1.75         2280
# 7396   1545803340  2/24/2015  269000.0         3       1.75         1530
# 5581    622100130  9/17/2014  365000.0         2       2.00         1440
# 4760   7399301100  12/4/2014  315000.0         3       1.75         1480
#
#        Sqft_Lot  Floors  Waterfront  View  ...  Grade  Sqft_Above  \
# 12130      7260     2.0         0.0   0.0  ...      8        2200
# 8751      16671     1.5         0.0   0.0  ...      6        1760
# 7396       7930     1.0         0.0   0.0  ...      7        1530
# 5581      15000     1.0         0.0   0.0  ...      7        1440
# 4760       6800     1.0         0.0   0.0  ...      7        1480
#
#        Sqft_Basement Yr_Built  Yr_Renovated  Zipcode      Lat     Long  \
# ...

# %%
# using query() to test some hypotheses
df.query('Bedrooms > Bathrooms')
# Out:
#                ID        Date     Price  Bedrooms  Bathrooms  Sqft_Living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        Sqft_Lot  Floors  Waterfront  View  ...  Grade  Sqft_Above  \
# ...

# %%
# checking how many columns are integers, floats or string
df.dtypes.value_counts()
# Out:
# int64      11
# float64     8
# object      2
# dtype: int64

# %%
# columns with type - object
df.select_dtypes(include=["object"]).columns
# Out:
# Index(['Date', 'Sqft_Basement'], dtype='object')

# %% [markdown]
# # Missing values

# %%
df.isnull().any()
# Out:
# ID               False
# Date             False
# Price            False
# Bedrooms         False
# Bathrooms        False
# Sqft_Living      False
# Sqft_Lot         False
# Floors           False
# Waterfront        True
# View              True
# Condition        False
# Grade            False
# Sqft_Above       False
# Sqft_Basement    False
# Yr_Built         False
# Yr_Renovated      True
# Zipcode          False
# Lat              False
# Long             False
# Sqft_Living15    False
# Sqft_Lot15       False
# dtype: bool

# %%
df.isna().sum()
# Out:
# ID                  0
# Date                0
# Price               0
# Bedrooms            0
# Bathrooms           0
# Sqft_Living         0
# Sqft_Lot            0
# Floors              0
# Waterfront       2376
# View               63
# Condition           0
# Grade               0
# Sqft_Above          0
# Sqft_Basement       0
# Yr_Built            0
# Yr_Renovated     3842
# Zipcode             0
# Lat                 0
# Long                0
# Sqft_Living15       0
# Sqft_Lot15          0
# dtype: int64

# %% [markdown]
# How to deal with missing values:
#
# 1. Deletion
# 2. Imputation
# 3. Estimation of values with the help of linear regression, ANOVA, logistic regression or other modelling technique
# 4. Implementation of KNN

# %%
# deletion
# df.dropna(axis=0) # rows
# df.dropna(axis=1) # columns

# %%
# imputation
# import numpy as np

# mean = np.mean(df["View"])
# df = df.View.fillna(mean)

# %%
# interpolation
# df.interpolate()

# %% [markdown]
# # Exploring relationship with our target

# %%
# for numeric columns we can use heatmap, correlation matrix to see their relationship with price
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
# we will be using corrwith() method to calculate pairwise correlation
# it automatically ignores non-numerical variables
correlations = df.corrwith(df["Price"]).iloc[3:].to_frame()
correlations["abs"] = correlations[0].abs()
sorted_correlations = correlations.sort_values("abs", ascending=False)[0]

fig, ax = plt.subplots(figsize=(10,20))
sns.heatmap(sorted_correlations.to_frame(), cmap="coolwarm", annot=True, vmin=-1, vmax=1, ax=ax)

# %%
# for categorical columns we will be using box plots to examine the relationships
plt.figure(figsize=(35,10))
sns.boxplot(df["Date"], df["Price"]).set_title("Date and Price");

# %%
plt.figure(figsize=(35,10))
sns.boxplot(df["Sqft_Basement"], df["Price"]).set_title("Basement and Price");

# %%
# ordinal columns
sns.boxplot(df["Bedrooms"], df["Price"]).set_title("Bedrooms and Price");

# %%
sns.boxplot(df["Waterfront"], df["Price"]).set_title("Waterfront vs. Price");

# %%
sns.boxplot(df["View"], df["Price"]).set_title("View vs. Price");

# %%
# floors
sns.boxplot(df["Floors"], df["Price"]).set_title("Floors vs. Price")
# Out:
# Text(0.5, 1.0, 'Floors vs. Price')

# %%
# bathrooms
sns.boxplot(df["Bathrooms"], df["Price"]).set_title("Bathrooms vs. Price");

# %%
# yr built
plt.figure(figsize=(35,10))
sns.boxplot(df["Yr_Built"], df["Price"]).set_title("Year Built and Price");

# %% [markdown]
# # Outliers

# %% [markdown]
# How to deal with outliers:
#
# 1. Deletion
# 2. Transformation - assigning weights to observations, using natural log to reduce variation
# 3. Imputation
#
# Depending on the data context

# %%
# checking for outliers
# bedrooms and price
sns.lmplot(x="Bedrooms", y="Price", data=df, fit_reg=False)

# %%
# getting index of the outliers
df.loc[df["Bedrooms"]>10]
# Out:
#                ID       Date     Price  Bedrooms  Bathrooms  Sqft_Living  \
# 8748   1773100755  8/21/2014  520000.0        11       3.00         3000
# 15856  2402100895  6/25/2014  640000.0        33       1.75         1620
#
#        Sqft_Lot  Floors  Waterfront  View  ...  Grade  Sqft_Above  \
# 8748       4960     2.0         0.0   0.0  ...      7        2400
# 15856      6000     1.0         0.0   0.0  ...      7        1040
#
#        Sqft_Basement Yr_Built  Yr_Renovated  Zipcode      Lat     Long  \
# 8748           600.0     1918        1999.0    98106  47.5560 -122.363
# 15856          580.0     1947           0.0    98103  47.6878 -122.331
#
#        Sqft_Living15  Sqft_Lot15
# 8748            1420        4960
# 15856           1330        4700
#
# [2 rows x 21 columns]

# %%
# dropping outliers
rows_to_drop = [8748, 15856]

for row in rows_to_drop:
    df.drop(row, inplace=True)

# %%
sns.lmplot(x="Bedrooms", y="Price", data=df, fit_reg=False)

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# 1. Factorize features - encoding categorical variables into numerical with factorize()
# 2. Bin continuous variables in groups with cut()
# 3. Scale features

# %% [markdown]
# # Feature Selection

# %% [markdown]
# It evaluates the quality and predictive power and selects the best set. Can use RandomForest for feature selection.

# %%
# Import `RandomForestClassifier`
from sklearn.ensemble import RandomForestClassifier

# Isolate Data, class labels and column values
X = iris.iloc[:,0:4]
Y = iris.iloc[:,-1]
names = iris.columns.values

# Build the model
rfc = RandomForestClassifier()

# Fit the model
rfc.fit(X, Y)

# Print the results
print("Features sorted by their score:")
print(sorted(zip(map(lambda x: round(x, 4), rfc.feature_importances_), names), reverse=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-a70a283bd56e> in <module>
#       3
#       4 # Isolate Data, class labels and column values
# ----> 5 X = iris.iloc[:,0:4]
#       6 Y = iris.iloc[:,-1]
#       7 names = iris.columns.values
#
# NameError: name 'iris' is not defined

# %%
# Import `pyplot` and `numpy`
import matplotlib.pyplot as plt
import numpy as np

# Isolate feature importances 
importance = rfc.feature_importances_

# Sort the feature importances 
sorted_importances = np.argsort(importance)

# Insert padding
padding = np.arange(len(names)-1) + 0.5

# Plot the data
plt.barh(padding, importance[sorted_importances], align='center')

# Customize the plot
plt.yticks(padding, names[sorted_importances])
plt.xlabel("Relative Importance")
plt.title("Variable Importance")

# Show the plot
plt.show()

# %% [markdown]
# # Patterns in Data

# %%
df_pca = df[[:,2:]]
# Out:
#   File "<ipython-input-40-4fea85f0771b>", line 1
#     df_pca = df[[:,2:]]
#                  ^
# SyntaxError: invalid syntax

# %%
# visualising correlation
# reduce dimensions first
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
reduced_data = pca.fit_transform(df_pca)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-4d1be0b2deeb> in <module>
#       4
#       5 pca = PCA(n_components=2)
# ----> 6 reduced_data = pca.fit_transform(df_pca)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/pca.py in fit_transform(self, X, y)
#     358
#     359         """
# --> 360         U, S, V = self._fit(X)
#     361         U = U[:, :self.n_components_]
#     362
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/decomposition/pca.py in _fit(self, X)
#     380
#     381         X = check_array(X, dtype=[np.float64, np.float32], ensure_2d=True,
# --> 382                         copy=self.copy)
#     383
#     384         # Handle n_components==None
#
# ...

# %%
# displaying relationships
plt.scatter(reduced_data[:0], reduced_data[:1], c=labels, cmap="viridis")
plt.show()

# %%
# or we can just simply use corr() function
df.corr()
# Out:
#                      ID     Price  Bedrooms  Bathrooms  Sqft_Living  Sqft_Lot  \
# ID             1.000000 -0.016765  0.002714   0.005197    -0.012214 -0.131934
# Price         -0.016765  1.000000  0.316504   0.525934     0.701948  0.089879
# Bedrooms       0.002714  0.316504  1.000000   0.528308     0.593780  0.033753
# Bathrooms      0.005197  0.525934  0.528308   1.000000     0.755742  0.088384
# Sqft_Living   -0.012214  0.701948  0.593780   0.755742     1.000000  0.173465
# Sqft_Lot      -0.131934  0.089879  0.033753   0.088384     0.173465  1.000000
# Floors         0.018619  0.256828  0.183648   0.502550     0.353913 -0.004813
# Waterfront    -0.004184  0.276297 -0.002269   0.067288     0.110235  0.023141
# View           0.011567  0.395739  0.081176   0.186468     0.282549  0.075292
# Condition     -0.023750  0.036029  0.023726  -0.126415    -0.059369 -0.008813
# Grade          0.008144  0.667967  0.367001   0.665889     0.762825  0.114721
# ...
